# %%
# Import libraries

import numpy as np
import pandas as pd
import matplotlib.pylab as plt2
import seaborn as sns
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor  
import graphviz
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from ggplot import *
import pydotplus

from sklearn import cross_validation
from sklearn.cross_validation import cross_val_score
from sklearn import metrics  
from sklearn.model_selection import train_test_split

# %%
# Import data

mp  = pd.read_csv('/Users/Felicia/Documents/Felicia Zhang/Felicia/Princeton/ConsultingClub/Mindprint/Mindprint_ScaledScores_YesCombo_112418.csv')
mp.set_index('customer_id', inplace=True)

print('Data size:',len(mp), 'rows')
# Out:
# Data size: 292 rows

# %%
mp.head()
# Out:
#              age   SM_Sz         SM_SCORE  VMEM_Az  VMEM_Sz  VMEM_efficiency  \
# customer_id
# 512           15  1.0190  medium_strength   0.6298   0.3895          0.50965
# 512           15  1.0190  medium_strength   0.6298   0.3895          0.50965
# 513           16  0.7039    high_expected   0.9644   1.1184          1.04140
# 517           17  1.7537    high_strength   0.6250   1.0837          0.85435
# 677           16  0.6158    high_expected  -0.0539   0.6653          0.30570
#
#                   VMEM_SCORE  ABF_Az  ABF_Sz  ABF_efficiency  \
# customer_id
# 512            high_expected -0.0704 -0.1611        -0.11575
# 512            high_expected -0.0704 -0.1611        -0.11575
# 513            high_expected  1.0407  1.0965         1.06860
# 517            high_expected  0.9616  0.2867         0.62415
# 677          medium_expected -1.9930  0.8253        -0.58385
#
#                     ...         DEPRESSION  ACTversion  EngRaw  MathRaw  \
# customer_id         ...
# 512                 ...                  0         70G    67.0     44.0
# 512                 ...                  0       Combo    56.0     33.0
# 513                 ...                  0         71E    59.0     36.0
# 517                 ...                  0         71A    70.0     44.0
# 677                 ...                  0         71C    51.0     23.0
#
#             ReadingRaw  ScienceRaw  EngScaledScore  MathScaledScore  \
# customer_id
# 512               36.0        26.0              29             26.0
# 512               54.0        46.0              18             16.0
# 513               29.0        15.0              26             23.0
# 517               35.0        27.0              32             27.0
# 677               30.0        18.0              22             17.0
#
#             ReadingScaledScore  ScienceScaledScore
# customer_id
# 512                       31.0                24.0
# 512                       21.0                19.0
# 513                       25.0                18.0
# 517                       31.0                24.0
# 677                       27.0                19.0
#
# [5 rows x 51 columns]

# %%
# Label students who received extra time: 2507 (don't have data), 2421, 4499, 6150, 517, 2010, 2948, 6171, 5866, 4967, 2720, 1872, 6808
mp['ExtraTime'] = 0

mp.loc[2421, 'ExtraTime'] = 1
mp.loc[4499, 'ExtraTime'] = 1
mp.loc[6150, 'ExtraTime'] = 1
mp.loc[517, 'ExtraTime'] = 1
mp.loc[2010, 'ExtraTime'] = 1
mp.loc[2948, 'ExtraTime'] = 1
mp.loc[6171, 'ExtraTime'] = 1
mp.loc[5866, 'ExtraTime'] = 1
mp.loc[4967, 'ExtraTime'] = 1
mp.loc[2720, 'ExtraTime'] = 1
mp.loc[1872, 'ExtraTime'] = 1
mp.loc[6808, 'ExtraTime'] = 1
mp.loc[8568, 'ExtraTime'] = 1
mp.loc[10266, 'ExtraTime'] = 1
mp.loc[8409, 'ExtraTime'] = 1

print('Number of students who received extra time:',len(mp.loc[mp['ExtraTime'] == 1]))
# Out:
# Number of students who received extra time: 17

# %%
# Replace outlier Mindprint scores (accuracy scores with < -2 with NAN)
# 1901: WM_Az, 5143: ATT_Az, 1902: ATT_Az, 6381: ATT_Az

print(mp.loc[1901, 'WM_Az'], mp.loc[5143, 'ATT_Az'], mp.loc[1902, 'ATT_Az'], mp.loc[6381, 'ATT_Az'])

mp.loc[1901, 'WM_Az'] = -2
mp.loc[5143, 'ATT_Az'] = -2
mp.loc[1902, 'ATT_Az'] = -2
mp.loc[6381, 'ATT_Az'] = -2

print(mp.loc[1901, 'WM_Az'], mp.loc[5143, 'ATT_Az'], mp.loc[1902, 'ATT_Az'], mp.loc[6381, 'ATT_Az'])
# Out:
# -6.8829 -4.2585 -4.2585 customer_id
# 6381   -5.6713
# 6381   -5.6713
# 6381   -5.6713
# 6381   -5.6713
# 6381   -5.6713
# 6381   -5.6713
# 6381   -5.6713
# Name: ATT_Az, dtype: float64
# -2.0 -2.0 -2.0 customer_id
# 6381   -2.0
# 6381   -2.0
# 6381   -2.0
# 6381   -2.0
# 6381   -2.0
# 6381   -2.0
# 6381   -2.0
# Name: ATT_Az, dtype: float64

# %%
# Remove students that having missing ACT subject scores

print('Number of students with missing ACT subject scores:',len(mp) - len(mp.dropna(subset=['EngScaledScore','MathScaledScore','ReadingScaledScore','ScienceScaledScore']))) 
mp = mp.dropna(subset=['EngScaledScore','MathScaledScore','ReadingScaledScore','ScienceScaledScore'])
# Out:
# Number of students with missing ACT subject scores: 11

# %%
# Calculate descriptive statistics

mp.describe().round(1)
# Out:
#          age  SM_Sz  VMEM_Az  VMEM_Sz  VMEM_efficiency  ABF_Az  ABF_Sz  \
# count  281.0  281.0    281.0    281.0            281.0   281.0   281.0
# mean    16.2    0.7      0.2      0.3              0.3     0.2     0.4
# std      0.8    0.6      0.7      0.6              0.5     1.1     1.0
# min     14.0   -1.8     -3.1     -1.6             -1.6    -3.9    -3.7
# 25%     16.0    0.4     -0.1     -0.1             -0.1    -0.3     0.0
# 50%     16.0    0.8      0.6      0.4              0.4     0.4     0.6
# 75%     17.0    1.1      0.6      0.8              0.7     0.9     0.9
# max     21.0    2.0      1.0      1.5              1.2     2.5     3.4
#
#        ABF_efficiency  LAN_Az  LAN_Sz    ...      DEPRESSION  EngRaw  MathRaw  \
# count           281.0   281.0   281.0    ...           281.0   265.0    265.0
# mean              0.3     0.5     0.2    ...             0.1    56.3     40.1
# std               0.8     0.5     0.8    ...             0.4    12.9     11.5
# min              -3.2    -1.4    -3.4    ...             0.0    24.0     12.0
# 25%               0.0     0.2    -0.3    ...             0.0    49.0     33.0
# 50%               0.4     0.6     0.3    ...             0.0    57.0     39.0
# 75%               0.8     1.0     0.8    ...             0.0    65.0     47.0
# max               1.8     1.1     1.4    ...             2.0    95.0     87.0
#
#        ReadingRaw  ScienceRaw  EngScaledScore  MathScaledScore  \
# count       265.0       265.0           281.0            281.0
# mean         31.7        29.9            23.6             23.5
# std          15.2        14.7             5.3              4.7
# min           7.0         6.0            10.0             15.0
# 25%          22.0        22.0            20.0             20.0
# 50%          28.0        26.0            23.0             24.0
# 75%          35.0        32.0            27.0             27.0
# max          96.0       100.0            35.0             35.0
#
#        ReadingScaledScore  ScienceScaledScore  ExtraTime
# count               281.0               281.0      281.0
# mean                 23.6                22.7        0.1
# std                   5.2                 3.9        0.2
# min                   9.0                10.0        0.0
# 25%                  20.0                20.0        0.0
# 50%                  23.0                23.0        0.0
# 75%                  28.0                25.0        0.0
# max                  34.0                36.0        1.0
#
# [8 rows x 40 columns]

# %%
# Only want the scaled subject scores

scores = mp.iloc[:,[-5,-4,-3,-2,-1]]
scores['TotalScore'] = scores.mean(axis=1).astype(int)
scores.head()
# Out:
# /Users/Felicia/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              EngScaledScore  MathScaledScore  ReadingScaledScore  \
# customer_id
# 512                      29             26.0                31.0
# 512                      18             16.0                21.0
# 513                      26             23.0                25.0
# 517                      32             27.0                31.0
# 677                      22             17.0                27.0
#
#              ScienceScaledScore  ExtraTime  TotalScore
# customer_id
# 512                        24.0          0          22
# 512                        19.0          0          14
# 513                        18.0          0          18
# 517                        24.0          1          23
# 677                        19.0          0          17

# %%
# Heatmap
# remove extratime column for the heatmap
scores2 = scores.drop('ExtraTime', 1)

fig = sns.heatmap(scores2.corr(),annot=True, cmap='RdPu')
plt2.show()

# %%
# Plot distribution of subject scores
fig1 = plt.figure(figsize=(15,15))
ax1 = fig1.add_subplot(321)
ax2 = fig1.add_subplot(322)
ax3 = fig1.add_subplot(323)
ax4 = fig1.add_subplot(324)
ax5 = fig1.add_subplot(325)

x = scores.loc[:,'EngScaledScore']
n, bins, patches = ax1.hist(x, len(scores.EngScaledScore.unique()), facecolor='blue', alpha=0.9)
ax1.set_title("English")
ax1.set_ylabel("Count")
ax1.set_xlabel("Scaled Score")
ax1.set_xlim(5,40,5)

x = scores.loc[:,'MathScaledScore']
n, bins, patches = ax2.hist(x, len(scores.MathScaledScore.unique()), facecolor='red', alpha=0.9)
ax2.set_title("Math")
ax2.set_ylabel("Count")
ax2.set_xlabel("Scaled Score")
ax2.set_xlim(5,40,5)

x = scores.loc[:,'ReadingScaledScore']
n, bins, patches = ax3.hist(x, len(scores.ReadingScaledScore.unique()), facecolor='purple', alpha=0.9)
ax3.set_title("Reading")
ax3.set_ylabel("Count")
ax3.set_xlabel("Scaled Score")
ax3.set_xlim(5,40,5)

x = scores.loc[:,'ScienceScaledScore']
n, bins, patches = ax4.hist(x, len(scores.ScienceScaledScore.unique()), facecolor='green', alpha=0.9)
ax4.set_title("Science")
ax4.set_ylabel("Count")
ax4.set_xlabel("Scaled Score")
ax4.set_xlim(5,40,5)

x = scores.loc[:,'TotalScore']
n, bins, patches = ax5.hist(x, len(scores.TotalScore.unique()), facecolor='orange', alpha=0.9)
ax5.set_title("Total ACT Score")
ax5.set_ylabel("Count")
ax5.set_xlabel("Avg of subject scaled scores")
ax5.set_xlim(5,40,5)

plt.show()

# %% [markdown]
# # Tree Model

# %%
###### Plan ######
# Use regression tree, 
# combine speed, accuracy and efficiency together
# Instead of trying to control tree depth, set sample split to 20 and 10
# run model with and without students who received extra time

# %%
# drop processing speed
mp = mp.drop('PROCESSING_SPEED_Sz', axis=1)

# %% [markdown]
# ## Reading - All subjects

# %%
# load data
X = mp.loc[:, mp.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores.loc[:, 'ReadingScaledScore'].copy()
  
# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %% [markdown]
# ## Reading - Removed extra time students

# %%
# load data
# drop students who received extra time
mp2 = mp[mp.ExtraTime != 1]
scores2 = scores[scores.ExtraTime != 1]

X = mp2.loc[:, mp2.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores2.loc[:, 'ReadingScaledScore'].copy()

# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %% [markdown]
# ## Math

# %%
# load data
X = mp.loc[:, mp.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores.loc[:, 'MathScaledScore'].copy()

# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %% [markdown]
# ## Math - Removed extra time students

# %%
# load data
# drop students who received extra time
mp2 = mp[mp.ExtraTime != 1]
scores2 = scores[scores.ExtraTime != 1]

X = mp2.loc[:, mp2.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores2.loc[:, 'MathScaledScore'].copy()

# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %% [markdown]
# ## Science

# %%
# drop visual motor speed, it didn't make sense for this model
mp3 = mp.drop('SM_Sz', axis=1) 

# load data
X = mp3.loc[:, mp3.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores.loc[:, 'ScienceScaledScore'].copy()

# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %% [markdown]
# ## Science - Removed extra time students

# %%
# load data
# drop students who received extra time
mp2 = mp3[mp3.ExtraTime != 1]
scores2 = scores[scores.ExtraTime != 1]

X = mp2.loc[:, mp2.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores2.loc[:, 'ScienceScaledScore'].copy()

# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %% [markdown]
# ## English

# %%
# load data
X = mp.loc[:, mp.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores.loc[:, 'EngScaledScore'].copy()

# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %% [markdown]
# ## English - Removed extra time students

# %%
# load data
# drop students who received extra time
mp2 = mp[mp.ExtraTime != 1]
scores2 = scores[scores.ExtraTime != 1]

X = mp2.loc[:, mp2.columns.str.contains('_Az|_Sz|_EFFICIENCY|_efficiency')].copy()
y = scores2.loc[:, 'EngScaledScore'].copy()

# Build final tree with min_sample = 10
foo = tree.DecisionTreeRegressor(min_samples_split=10, min_samples_leaf=10)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph

# %%
# Build final tree with min_sample = 20
foo = tree.DecisionTreeRegressor(min_samples_split=20, min_samples_leaf=20)  
foo = foo.fit(X, y)
foo2 = tree.export_graphviz(foo, out_file=None, feature_names=X.columns, #class_names=["above", "below"], 
                                filled=True, rounded=True, special_characters=True)

graph = graphviz.Source(foo2)
graph
